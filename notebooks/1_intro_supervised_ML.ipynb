# %% [markdown]
# ## Introduction to Supervised Machine Learning
# **Instructor:** Lisa-Marie Rolli, Volkamer Lab, Saarland University (lisa-marie.rolli@uni-saarland.de)
#
#
# **Workshop date:** 2nd September 2026
#
# **Further reading**: A gentle introduction into statistical learning with Python or R can be found in the textbook ["An introduction to statistical learning" by James et al.](https://www.statlearning.com/).

# %% [markdown]
# Machine learning (ML) is a research area in computer science, where algorithms are developed to learn from data. Generally, ML can be subdivided into four major realms: (i) supervised learning, (ii) unsupervised learning, (iii) semi-supervised learning, and (iv) reinforcement learning. In this notebook, we focus on supervised ML. In supervised ML, an algorithm learns to predict a specific *response* (e.g., toxicity) for a sample (e.g., compound) based on *features* of the sample (e.g., physicochemical propteries). The learning is based on the assumption that there is a functional relationship between the features and the response, which we can approximate. There exist a plethora of different algorithms, which mainly differ in their assumptions about the true relationship and their learning algorithm, i.e., how they approximate the true function. In this tutorial we will start with linear regression, which assumes a linear relationship between the features and the response.

# %% [markdown]
# ### Data
# As mentioned above, the dataset must consist of *features*, i.e., descriptors of the samples, and a *response*, i.e., a measurement that we want to predict. The goal is to learn a relationship between the features and the response for a given *training set* of samples so that we can later predict for *unseen* samples. In particular, we always separate a hold out *test set*, which is used to evaluate how well our model predicts for samples that it has not seen during training.
#
# The most important step in the ML pipeline is the data processing. In the following, we first download the [AqSolDB dataset](https://doi.org/10.1038/s41597-019-0151-1) from our GitHub, as this is our toy dataset for this tutorial. AqSolDB is curated by [AMD](https://www.nature.com/articles/s41597-019-0151-1) and we downloaded it from [Kaggel](https://www.kaggle.com/datasets/sorkun/aqsoldb-a-curated-aqueous-solubility-dataset?resource=download) on 11.Jul.2025

# %% [markdown]
# To run this notebook, we require python 3.12, as newer versions are not compatible with the library `datasail` that we are using. When you are using google colab, you should therefore change the runtime version to `2026.01`.

# %%
import sys

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # !pip install rdkit
    # !pip install datasail
    # !wget https://raw.githubusercontent.com/volkamerlab/ai_in_chemistry_workshop_2026/refs/heads/main/notebooks/data/solubility_values.tsv
    # !wget https://raw.githubusercontent.com/volkamerlab/ai_in_chemistry_workshop_2026/refs/heads/main/notebooks/data/smiles.tsv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from datasail.sail import datasail
from sklearn.metrics import r2_score, mean_absolute_error
from rdkit import Chem, RDLogger 
from rdkit.Chem import Draw, Descriptors, rdMolDescriptors
from rdkit.Chem import PandasTools
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import pearsonr
RDLogger.DisableLog('rdApp.*')

# %%
if not IN_COLAB:
    smiles_df = pd.read_csv('data/smiles.tsv', sep = '\t', index_col = 0)
else:
    smiles_df = pd.read_csv('smiles.tsv', sep = '\t', index_col = 0)
smiles_df.head()
# Out:
#                                                         SMILES
# compound_id
# 817354021                  [Br-].CCCCCCCCCCCCCCCCCC[N+](C)(C)C
# 884077896                                 O=C1Nc2cccc3cccc1c23
# 100491263                                      Clc1ccc(C=O)cc1
# 650290313    [Zn++].CC(c1ccccc1)c2cc(C(C)c3ccccc3)c(O)c(c2)...
# 324766667    C1OC1CN(CC2CO2)c3ccc(Cc4ccc(cc4)N(CC5CO5)CC6CO...

# %% [markdown]
# Most ML models are not able to directly process text, e.g., SMILES strings. Therefore, we calculate numerical descriptors that are easier for the model to understand. One of the most simple representations are physicochemical properties that we can calculate using RDKit. RDKit is a library that can (among other things) read SMILES and store them as a molecule.

# %% [markdown]
# Now, we want to calculate the LogP for all molecules in our ```smiles_df``` data frame, as we think, it should have some predictive information that can be leveraged when prediciting solubility. First, we convert all SMILES strings in our dataframe to molecules.

# %%
# ensure that molecules are displayed in dataframe
PandasTools.RenderImagesInAllColumns = True

PandasTools.AddMoleculeColumnToFrame(smiles_df, "SMILES", molCol='molecule')
smiles_df.dropna(inplace = True)
smiles_df
# Out:
#                                                         SMILES  \
# compound_id
# 817354021                  [Br-].CCCCCCCCCCCCCCCCCC[N+](C)(C)C
# 884077896                                 O=C1Nc2cccc3cccc1c23
# 100491263                                      Clc1ccc(C=O)cc1
# 650290313    [Zn++].CC(c1ccccc1)c2cc(C(C)c3ccccc3)c(O)c(c2)...
# 324766667    C1OC1CN(CC2CO2)c3ccc(Cc4ccc(cc4)N(CC5CO5)CC6CO...
# ...                                                        ...
# 624359319                       C(c1ccc(cc1)NCCCC)(=O)OCCN(C)C
# 215150761    OC1=C(C(C2=C(O)[C@@](C(C(C(N)=O)=C(O)[C@H]3N(C...
# 259287587                                  c1(cc(ccc1C(C)C)C)O
# 276753938    COc1ccc(CCN(C)CCCC(C#N)(C(C)C)c2ccc(OC)c(OC)c2...
# 654468933                CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#                                                       molecule
# compound_id
# 817354021    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...
# 884077896    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...
# 100491263    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...
# 650290313    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...
# 324766667    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...
# ...                                                        ...
# 624359319    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...
# 215150761    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...
# 259287587    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...
# 276753938    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...
# 654468933    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...
#
# [9980 rows x 2 columns]

# %% [markdown]
# Then, we calculate the LogP for all molecules in the dataframe. If we were not able to calculate the LogP for any of the comounds, we remove it, because we don't have a descriptor that we could use for our prediction.

# %%
smiles_df["logp"] = smiles_df["molecule"].apply(Descriptors.MolLogP)
smiles_df["molwt"] = smiles_df["molecule"].apply(Descriptors.MolWt)
smiles_df["hbd"] = smiles_df["molecule"].apply(rdMolDescriptors.CalcNumHBD)
smiles_df["hba"] = smiles_df["molecule"].apply(rdMolDescriptors.CalcNumHBA)
smiles_df["tpsa"] = smiles_df["molecule"].apply(Descriptors.TPSA)
# if we have missing values, we remove the molecules
smiles_df.dropna(inplace=True)
smiles_df
# Out:
#                                                         SMILES  \
# compound_id
# 817354021                  [Br-].CCCCCCCCCCCCCCCCCC[N+](C)(C)C
# 884077896                                 O=C1Nc2cccc3cccc1c23
# 100491263                                      Clc1ccc(C=O)cc1
# 650290313    [Zn++].CC(c1ccccc1)c2cc(C(C)c3ccccc3)c(O)c(c2)...
# 324766667    C1OC1CN(CC2CO2)c3ccc(Cc4ccc(cc4)N(CC5CO5)CC6CO...
# ...                                                        ...
# 624359319                       C(c1ccc(cc1)NCCCC)(=O)OCCN(C)C
# 215150761    OC1=C(C(C2=C(O)[C@@](C(C(C(N)=O)=C(O)[C@H]3N(C...
# 259287587                                  c1(cc(ccc1C(C)C)C)O
# 276753938    COc1ccc(CCN(C)CCCC(C#N)(C(C)C)c2ccc(OC)c(OC)c2...
# 654468933                CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#                                                       molecule     logp  \
# compound_id
# 817354021    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...  3.95810
# 884077896    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...  2.40550
# 100491263    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...  2.15250
# 650290313    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...  8.11610
# 324766667    <rdkit.Chem.rdchem.Mol object at 0x0000027D172...  2.48540
# ...                                                        ...      ...
# 624359319    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...  2.61700
# 215150761    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE... -0.21440
# 259287587    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...  2.82402
# 276753938    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...  5.09308
# 654468933    <rdkit.Chem.rdchem.Mol object at 0x0000027D2DE...  3.60960
#
#                molwt  hbd  hba    tpsa
# compound_id
# 817354021    392.510    0    0    0.00
# 884077896    169.183    1    1   29.10
# 100491263    140.569    0    1   17.07
# 650290313    756.226    2    6  120.72
# 324766667    422.525    0    6   56.60
# ...              ...  ...  ...     ...
# 624359319    264.369    1    4   41.57
# 215150761    444.440    6    9  181.62
# 259287587    150.221    1    1   20.23
# 276753938    454.611    0    6   63.95
# 654468933    308.333    1    4   67.51
#
# [9980 rows x 7 columns]

# %% [markdown]
# Now, we load the target, i.e., the continuous solubility values LogS, that we want to predict.

# %%
if not IN_COLAB:
    response_df = pd.read_csv('data/solubility_values.tsv', sep = '\t', index_col = 0)
else:
    response_df = pd.read_csv('solubility_values.tsv', sep = '\t', index_col = 0)
response_df.head()
# Out:
#                  LogS
# compound_id
# 817354021   -3.616127
# 884077896   -3.254767
# 100491263   -2.177078
# 650290313   -3.924409
# 324766667   -4.662065

# %% [markdown]
# As not all molecules are necessarily tested in all assays, we now only take the intersection of molecules with available properties and response.

# %%
considered_mols = list(set(smiles_df.index).intersection(set(response_df.index)))
X = smiles_df.loc[considered_mols, ['logp', 'molwt', 'hbd', 'hba', 'tpsa']]
y = response_df.loc[considered_mols]
print(f'We have {len(considered_mols)} molecules in our dataset.')
# Out:
# We have 9980 molecules in our dataset.

# %% [markdown]
# Now, we can have a look at the response plotted with respect to the different features (physicochemical properties) that we calculated before:

# %%
fig, ax = plt.subplots(ncols=len(X.columns), figsize=(10, 5), sharex=False, sharey=True)

for i, descriptor in enumerate(X.columns):
    r, p = pearsonr(X[descriptor].values, y['LogS'].values)
    ax[i].scatter(X[descriptor], y )
    ax[i].text(
    0.98, 0.98,
    f"r = {r:.2f}",
    transform=ax[i].transAxes,
    ha = "right",
    va="top"
    )
    ax[i].set(xlabel=descriptor)
    
ax[0].set(ylabel="LogS")
# Optional: add a little padding so points on the edge aren’t cut off


plt.tight_layout()
plt.show()

# %% [markdown]
# We see that LogP has the highest anti-correlation to our response. Therefore, we will first focus only on this descriptor for our model building.

# %% [markdown]
# ## Train and Test Set
# As already mentioned above, we need two disjoint sets for training and for testing. Typically, the training set accounts for ~80% of the original dataset, while the remaining 20% are used for testing. The most easy way to split the data is to split the compounds randomly. However, as we want the model to generalize well across the chemical space, we make sure that similar compounds will be in the same set. To this end, we use a software called [`datasail`](https://datasail.readthedocs.io/en/latest/) that calculates the distance between the molecular fingerprints and splits the data so that the distance between the two sets is maximized.

# %%
e_splits, _, _ = datasail(
    techniques=["C1e"],
    splits=[8, 2],
    names=["train", "test"],
    runs=3,
    solver="SCIP",
    e_type="M",
    e_data=dict(zip(smiles_df.index, smiles_df["SMILES"].values.tolist())),
)
split = e_splits['C1e'][0]
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:04:48 PM: Your problem has 49 variables, 50 constraints, and 0 parameters.
# (CVXPY) Aug 28 01:04:49 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:04:49 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:04:49 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:04:49 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:49 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:04:49 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:04:49 PM: Applying reduction Dcp2Cone
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cvxpy\problems\problem.py:158: UserWarning: Objective contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn("Objective contains too many subexpressions. "
# (CVXPY) Aug 28 01:04:49 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:04:49 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:04:49 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:04:49 PM: Finished problem compilation (took 7.558e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:49 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:49 PM: Problem status: optimal
# (CVXPY) Aug 28 01:04:49 PM: Optimal value: 0.000e+00
# (CVXPY) Aug 28 01:04:49 PM: Compilation took 7.558e-01 seconds
# (CVXPY) Aug 28 01:04:49 PM: Solver (including time spent in interface) took 2.693e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:04:49 PM: Your problem has 49 variables, 50 constraints, and 0 parameters.
# (CVXPY) Aug 28 01:04:49 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:04:49 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:04:50 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:04:50 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:50 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:04:50 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:04:50 PM: Finished problem compilation (took 5.006e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:50 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:50 PM: Problem status: optimal
# (CVXPY) Aug 28 01:04:50 PM: Optimal value: 0.000e+00
# (CVXPY) Aug 28 01:04:50 PM: Compilation took 5.006e-01 seconds
# (CVXPY) Aug 28 01:04:50 PM: Solver (including time spent in interface) took 2.765e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:04:50 PM: Your problem has 49 variables, 50 constraints, and 0 parameters.
# (CVXPY) Aug 28 01:04:50 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:04:50 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:04:50 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:04:50 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:50 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:04:50 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:04:50 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:04:51 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:04:51 PM: Finished problem compilation (took 5.077e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:51 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:04:51 PM: Problem status: optimal
# (CVXPY) Aug 28 01:04:51 PM: Optimal value: 0.000e+00
# (CVXPY) Aug 28 01:04:51 PM: Compilation took 5.077e-01 seconds
# (CVXPY) Aug 28 01:04:51 PM: Solver (including time spent in interface) took 3.165e-02 seconds

# %% [markdown]
# Now, we use the datasail output to split our features and responses into train and test.

# %%
train_samples = []
test_samples = []

for sample in split.keys():
    if split[sample] == 'train':
        train_samples.append(sample)
    else:
        test_samples.append(sample)

X_train = pd.DataFrame(X.loc[train_samples, 'logp'])
X_test = pd.DataFrame(X.loc[test_samples, 'logp'])
y_train = y.loc[train_samples, :]
y_test = y.loc[test_samples, :]

# %% [markdown]
# And we plot the train and test distribution for our feature (LogP) and response (LogS.)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 5), sharex='row', sharey=True)


ax[0].scatter(X_train, y_train, label = 'Train set')
ax[0].set(xlabel='LogP', ylabel = 'LogS')
ax[1].scatter(X_test, y_test, label="Test set")
ax[1].set(xlabel='LogP')
ax[0].set(title = 'Train set')
ax[1].set(title = 'Test set')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Training
# We fit on the training set and predict on the test set. For the fit, we use *least square regression*.

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %% [markdown]
# The least square regression calculates the squared difference between all training datapoints and the current line (the prediction) and adjusts the slope and intercept of the line so that the difference between actual datapoints and prediction is minimized.

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Scatter points
ax.scatter(X_train, y_train, label="Training points")

train_prediction = regressor.predict(X_train)
# Regression line
ax.plot(X_train, train_prediction, color="tab:orange", lw=2.5)

# Residuals: vertical segments from each point to the line at the same x
for xi, yi, yhi in zip(X_train.values, y_train.values, train_prediction):
    ax.vlines(xi, ymin=min(yi, yhi), ymax=max(yi, yhi),
                color="gray", linestyle="--", lw=1.5)


# Formatting
ax.set_xlabel("LogP")
ax.set_ylabel("LogS")
title = "Least Squares Illustration (vertical residuals)"

ax.set_title(title)
ax.margins(x=0.05, y=0.1)
ax.grid(True, alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# After fitting the regression line, we can use it to predict for any new data point in our test set:

# %%
fig, ax = plt.subplots(ncols=2,  figsize=(20,5), sharex='row', sharey=True)


ax[0].scatter(X_train, y_train, label = 'Train set')
ax[0].set(xlabel='LogP', ylabel = 'LogS')
ax[0].plot(X_train,regressor.predict(X_train),linewidth=3,color="tab:orange", label="Model predictions")
ax[1].scatter(X_test, y_test, label="Test set")
ax[1].set(xlabel='LogP')
ax[1].plot(X_test, y_pred, linewidth=3, color="tab:orange", label="Model predictions")

ax[0].set(title = 'Train set')
ax[1].set(title = 'Test set')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Performance Evaluation
# From looking at this plot, we can guess that this model does not predict really well. To quantify how good/bad a model *performs*, we use performance metrics such as the mean absolute error (MAE), which tells us how much our prediction $\hat{y}_i$ for a sample $i$ differs from the true value $y_i$ averaged over the number of samples $n$:
#
# $MAE = \frac{1}{n} \cdot \sum_{i = 1}^{n}\vert \hat{y}_i - y_i\vert$
#
# The value is in the same unit as the response (in our case the LogS). Thus, the judgement on whether the observed value is good or bad depends on the dataset. Another metric that is easier to interpret is the *coefficient of determination ($R^2$)*. It is a value in $(-\inf, 1]$, which tells you whether your model was better ($>0$) or worse ($<0$) than simply predicting the mean $\bar{y}$ of the test set.
#
# $R^2 = 1 - \frac{\sum_{i = 1}^{n} (\hat{y}_i - y_i)^2}{\sum_{i = 1}^{n} (\bar{y} - y_i)^2}$

# %%
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# Mean absolute error: 2.50
# Coefficient of determination: -0.46

# %% [markdown]
# The metrics reveal what we could already guess from our plot: The model does not perform well. Remember, however, that we only predict the LogS based on the LogP. Thus, the next step is to include all [217 physicochemical descriptors](https://www.rdkit.org/docs/source/rdkit.Chem.Descriptors.html#rdkit.Chem.Descriptors.CalcMolDescriptors) to obtain better predictions.

# %%
smiles_df['descriptors'] = smiles_df['molecule'].apply(Descriptors.CalcMolDescriptors)

# %%
X = smiles_df['descriptors'].apply(pd.Series)
X.dropna(inplace=True)
X = X.astype('float32')
X = X.loc[:, ~X.isin([-np.inf,np.inf ]).any()]
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\astype.py:136: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=copy)

# %%
y = y.loc[X.index, :]

train_samples = list(set(train_samples).intersection(set(X.index)))
test_samples = list(set(test_samples).intersection(set(X.index)))

X_train = X.loc[train_samples, :]
X_test = X.loc[test_samples, :]
y_train = y.loc[train_samples, :]
y_test = y.loc[test_samples, :]

# when using more than one feature, we standardize them so that 
# the model does not give to much weight to features with 
# naturally higher ranges 
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

linear_model = LinearRegression(n_jobs=-1, fit_intercept=True, positive=True)
linear_model.fit(X_train_scaled, y_train)
y_pred = linear_model.predict(X_test_scaled)
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# Mean absolute error: 1.97
# Coefficient of determination: -0.33

# %% [markdown]
# ## More Advanced Models
# As we can see, the model trained on all descriptors actually performs worse than the one only trained on LogP. Thus, we conclude that our linear model could not capture the real underlying complexity of our data, as we assume linearity. Therefore, we now use a more complex model, i.e., a random forest (RF).

# %%
rf = RandomForestRegressor(random_state=42, n_estimators=500, n_jobs=-1)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean absolute error: 0.73
# Coefficient of determination: 0.76

# %% [markdown]
# As we can see, the RF works well for this dataset with a $R^2$ of around 0.7. Maybe using a even more complex model, e.g., a neural network improves the performance?

# %%
mlp = MLPRegressor(random_state = 42)
mlp.fit(X_train_scaled, y_train)
y_pred = mlp.predict(X_test_scaled)
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1775: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean absolute error: 1.23
# Coefficient of determination: -0.54

# %% [markdown]
# As we can see, the neural network did not perform as good as the RF, which might be because of the limited number of samples (<10,000).

# %% [markdown]
# ## Interpretability of ML Models
#
# The RF was the best model in our analysis. Yet, we do not know how it comes to its predictions, but we just know what it outputs. To better understand its decisions, we now analyse the importance of the different features (i.e., physchem properties) for our prediciton. To this end, we use feature importance scores that indicate how important the feature was to the model during the training process. We plot the importances of the top ten features.

# %%
importances = rf.feature_importances_
feature_names = X_train.columns

top_k = 10
indices = np.argsort(importances)[-top_k:][::-1]  # top k, descending
top_features = feature_names[indices]
top_importances = importances[indices]



plt.figure(figsize=(8, 5))
bars = plt.barh(range(top_k), top_importances[::-1], color="#4e79a7")
plt.yticks(range(top_k), top_features[::-1])
plt.xlabel("Feature Importance")
plt.title("Top 10 Feature Importances — Random Forest")
plt.gca()  # highest at top
# Optional: add value labels
for i, v in enumerate(top_importances[::-1]):
    plt.text(v, i, f"{v:.2f}", va="center")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bonus
#
# ## Training and Interpreting ML Models on Morgan Fingerprints
#
# The RDKit descriptors are only one possible compound representation. Another, frequently used one, are the Morgan fingerprints, which are based on the extended connectivity fingerprint (ECFP) algorithm. Thus, we now show
# 1. how to train an RF on Morgan fingerprints,
# 2. compare its performance to the one trained on the RDKit descriptors, and
# 3. finally interpret the bits with the highest feature importance.

# %%
from rdkit import DataStructs
from rdkit.Chem import rdFingerprintGenerator

fpgen = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

fp_df = pd.DataFrame(
    [
        DataStructs.ConvertToNumpyArray(
            fpgen.GetFingerprint(m),
            arr := np.zeros(2048, dtype=np.int8)
        ) or arr
        for m in smiles_df["molecule"]
    ],
    index=smiles_df.index,
)

fp_df.index.name = "compound_id"

# %%
X_train_fp = fp_df.loc[train_samples, :]
X_test_fp = fp_df.loc[test_samples, :]

# %%
rf = RandomForestRegressor(random_state=42, n_estimators=500, n_jobs=-1)
rf.fit(X_train_fp, y_train)
y_pred = rf.predict(X_test_fp)
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean absolute error: 1.34
# Coefficient of determination: 0.30

# %% [markdown]
# We see that the coefficient of determination for this model is positive and it is the second best model that we trained today; however, for this specific dataset and split the RF on physicochemical properties performed better.

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import rdMolDraw2D
import io
from PIL import Image as PilImage

def mol_to_img_with_highlight(mol, center_atom, size=(200,200)):
    drawer = rdMolDraw2D.MolDraw2DCairo(size[0], size[1])
    opts = drawer.drawOptions()
    opts.addAtomIndices = True
    opts.bondLineWidth = 2
    opts.padding = 0.05

    # make all atoms gray by default
    opts.useBWAtomPalette()

    # highlight center atom in bright yellow
    atom_colors = {center_atom: (1.0, 1.0, 0.0)}

    rdMolDraw2D.PrepareAndDrawMolecule(
        drawer, mol, highlightAtoms=[center_atom], highlightAtomColors=atom_colors
    )
    drawer.FinishDrawing()
    return PilImage.open(io.BytesIO(drawer.GetDrawingText()))

def add_mol_image(ax, mol, center_atom, x, y, zoom=0.4):
    if mol is None:
        return
    img = mol_to_img_with_highlight(mol, center_atom=center_atom, size=(180,180))
    im = OffsetImage(img, zoom=zoom)
    ab = AnnotationBbox(im, (x,y), frameon=False, xybox=(0,40),
                        xycoords='data', boxcoords="offset points", pad=0)
    ax.add_artist(ab)

# %%
def plot_top_rf_bits_with_substructures(importances, bit_idx, mols, bitinfos, k=10):
    order = np.argsort(importances)[::-1]
    top_idx = order[:k]
    top_bits = bit_idx[top_idx]
    top_imps = importances[top_idx]

    fig, ax = plt.subplots(figsize=(12,6))
    x = range(k)
    ax.bar(x, top_imps, color="darkorange")
    ax.set_xticks(x)
    ax.set_xticklabels(top_bits, rotation=90)
    ax.set_xlabel("Morgan bit index")
    ax.set_ylabel("RF feature importance")
    ax.set_title(f"Top {k} RF feature importances (Morgan bits)")

    ylim_max = (top_imps.max() if len(top_imps) else 0) * 1.3
    ax.set_ylim(0, ylim_max if ylim_max > 0 else 1)

    # Try to overlay substructure images
    for i, bit in enumerate(top_bits):
        placed = False
        for mol, info in zip(mols, bitinfos):
            if bit in info:
                atom_idx, rad = info[bit][0]
                env = Chem.FindAtomEnvironmentOfRadiusN(mol, rad, atom_idx)
                if not env:  # fallback if lone atom
                    env = Chem.FindAtomEnvironmentOfRadiusN(mol, 1, atom_idx)

                atom_map = {}
                submol = Chem.PathToSubmol(mol, env, atomMap=atom_map)

                if atom_idx in atom_map:  # ✅ only highlight if mapping exists
                    center_atom_submol = atom_map[atom_idx]
                    add_mol_image(ax, submol, center_atom=center_atom_submol,
                                  x=i, y=top_imps[i])
                    placed = True
                    break
        if not placed:
            print(f"⚠️ Skipping bit {bit} (could not map atom index)")

    plt.tight_layout()
    plt.show()


# --- Usage ---
importances = rf.feature_importances_
bit_idx = np.arange(X_train_fp.shape[1])
mols = smiles_df['molecule'].values
bitinfos = []
for mol in mols:
    info = {}
    # radius must match your fingerprint generator (e.g. 2 for Morgan radius=2)
    _ = AllChem.GetMorganFingerprintAsBitVect(
        mol,
        radius=2,
        nBits=X_train_fp.shape[1],
        bitInfo=info
    )
    bitinfos.append(info)
plot_top_rf_bits_with_substructures(importances, bit_idx, mols, bitinfos, k=10)

# %% [markdown]
# ## Even More Advanced Workflows
#
# When working with ML models, we always have parameters that we have to adjust based on the given data, e.g., for the linear model we adjusted the slope and the y-intercept. When having more complex models there are also so-called hyperparameters, which are the parameters that already define parts of the model, e.g., the number of trees in a random forest. The hyperparameters have to be selected before training, but ideally we would like to select them based on the data. Therefore, we use a method called k-fold CV, where we split the training set into k parts and in each of the k iterations, we use another part for testing and the remaining k-1 parts for training. By this we can already estimate the error on the real test set and make informed decisions without leaking information from the test set.

# %% [markdown]
# First, we split the training data into 5 folds for a 5-fold CV.

# %%
e_splits, _, _ = datasail(
    techniques=["C1e"],
    splits=[0.2 for i in range(5)],
    names=[f'fold{i}' for i in range(1,6)],
    runs=3,
    solver="SCIP",
    e_type="M",
    e_data=dict(zip(X_train.index, smiles_df.loc[X_train.index, "SMILES"].values.tolist())),
)
split = e_splits['C1e'][0]
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:09:32 PM: Your problem has 250 variables, 55 constraints, and 0 parameters.
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cvxpy\problems\problem.py:158: UserWarning: Objective contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn("Objective contains too many subexpressions. "
# (CVXPY) Aug 28 01:09:32 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:09:32 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:09:32 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:09:32 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:09:32 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:09:32 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:09:32 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 28 01:09:33 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:09:33 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:09:34 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:09:34 PM: Finished problem compilation (took 1.544e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:09:34 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:11:14 PM: Problem status: optimal_inaccurate
# (CVXPY) Aug 28 01:11:14 PM: Optimal value: 2.750e+06
# (CVXPY) Aug 28 01:11:14 PM: Compilation took 1.544e+00 seconds
# (CVXPY) Aug 28 01:11:14 PM: Solver (including time spent in interface) took 9.998e+01 seconds
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cvxpy\problems\problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:11:14 PM: Your problem has 250 variables, 55 constraints, and 0 parameters.
# (CVXPY) Aug 28 01:11:14 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:11:14 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:11:14 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:11:14 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:11:14 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:11:14 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:11:14 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 28 01:11:15 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:11:15 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:11:16 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:11:16 PM: Finished problem compilation (took 1.570e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:11:16 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:12:56 PM: Problem status: optimal_inaccurate
# (CVXPY) Aug 28 01:12:56 PM: Optimal value: 2.740e+06
# (CVXPY) Aug 28 01:12:56 PM: Compilation took 1.570e+00 seconds
# (CVXPY) Aug 28 01:12:56 PM: Solver (including time spent in interface) took 9.985e+01 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.5.3
# ===============================================================================
# (CVXPY) Aug 28 01:12:56 PM: Your problem has 250 variables, 55 constraints, and 0 parameters.
# (CVXPY) Aug 28 01:12:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 28 01:12:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 28 01:12:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 28 01:12:56 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:12:56 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Aug 28 01:12:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Aug 28 01:12:56 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 28 01:12:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 28 01:12:57 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 28 01:12:58 PM: Applying reduction SCIP
# (CVXPY) Aug 28 01:12:58 PM: Finished problem compilation (took 1.628e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:12:58 PM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 28 01:14:38 PM: Problem status: optimal_inaccurate
# (CVXPY) Aug 28 01:14:38 PM: Optimal value: 2.745e+06
# (CVXPY) Aug 28 01:14:38 PM: Compilation took 1.628e+00 seconds
# (CVXPY) Aug 28 01:14:38 PM: Solver (including time spent in interface) took 9.980e+01 seconds

# %%
folds = {}
for sample in split.keys():
    fold = split[sample]
    if not fold in folds.keys():
        folds[fold] = [sample]
    else:
        folds[fold].append(sample)

# %%
best_score = -np.inf
best_trees = None
for n_trees in [200, 500, 700]:
    r2s = []
    for i in range(1,6):
        fold = f'fold{i}'
        test_part = X_train.loc[folds[fold], :]
        train_folds = set(f'fold{j}' for j in range(1,6))
        train_folds.remove(fold)
        train_part_samples = np.concatenate([folds[f] for f in train_folds])
        train_part = X_train.loc[train_part_samples, :]
        train_response = y_train.loc[train_part_samples, :]
        test_response = y_train.loc[folds[fold], :]
        rf = RandomForestRegressor(random_state=42, n_estimators=n_trees, n_jobs=-1)
        rf.fit(train_part, train_response)
        test_predict = rf.predict(test_part)
        r2s.append(r2_score(test_predict, test_response))
    mean_performance = np.mean(r2s)
    print(f'5-fold CV done for #trees = {n_trees}.')
    print(f'Average performance of {mean_performance}.')
    if  mean_performance > best_score:
        best_score = mean_performance
        best_trees = n_trees
print(f'The best number of trees is {best_trees}.')
print(f'The model had on average an R2 of {best_score}.')
rf_final = RandomForestRegressor(random_state=42, n_estimators=best_trees)
rf_final.fit(X_train,y_train)
y_pred = rf_final.predict(X_test)
print('Performance on the test set:')
print(f"Mean absolute error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 5-fold CV done for #trees = 200.
# Average performance of 0.7056779210137066.
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 5-fold CV done for #trees = 500.
# Average performance of 0.7084198760181191.
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 5-fold CV done for #trees = 700.
# Average performance of 0.7088317849231218.
# The best number of trees is 700.
# The model had on average an R2 of 0.7088317849231218.
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Performance on the test set:
# Mean absolute error: 0.73
# Coefficient of determination: 0.76
